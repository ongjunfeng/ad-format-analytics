# %%
from main import main

# %%
scraping_res, df = main()
# Out:
# INFO:data_scraper:Status: RUNNING, Message:
# INFO:data_scraper:2025-10-05T10:24:14.878Z ACTOR: Pulling Docker image of build z9vTe3ASFqaNiCgoa from registry.
# INFO:data_scraper:2025-10-05T10:24:14.880Z ACTOR: Creating Docker container.
# INFO:data_scraper:2025-10-05T10:24:14.934Z ACTOR: Starting Docker container.
# INFO:data_scraper:2025-10-05T10:24:16.085Z INFO  System info {"apifyVersion":"3.4.4","apifyClientVersion":"2.12.2","crawleeVersion":"3.13.2","osType":"Linux","nodeVersion":"v20.19.5"}
# WARNING:data_scraper:2025-10-05T10:24:16.248Z WARN  includeSharesCount is not supported for free users
# WARNING:data_scraper:2025-10-05T10:24:16.250Z WARN  [Status message]: includeSharesCount is not supported for free users
# INFO:data_scraper:2025-10-05T10:24:16.286Z INFO  Results Limit [object Object], ACTOR_MAX_PAID_DATASET_ITEMS
# INFO:data_scraper:2025-10-05T10:24:16.406Z INFO  [Status message]: Starting the scraper with 36 direct URL(s)
# ...

# %%
scraping_res.execution_time
# Out:
# 311.27689480781555

# %%
df
# Out:
#                        id   type    shortCode  ... paidPartnership sponsors isPinned
# 0     3702705301280394830  Video  DNiptqOxg5O  ...             NaN      NaN      NaN
# 1     3604851997572006807  Video  DIHAcrfIwOX  ...             NaN      NaN      NaN
# 2     2610269383037198069  Video  CQ5iiyQAp71  ...             NaN      NaN      NaN
# 3     3710666052864158719  Video  DN-7x15Eav_  ...             NaN      NaN      NaN
# 4     3421710919083191614  Video  C98W_OwB20-  ...             NaN      NaN      NaN
# ...                   ...    ...          ...  ...             ...      ...      ...
# 1734  3716822852739230981  Video  DOUzrEmk20F  ...             NaN      NaN      NaN
# 1735  3694827508670593377  Video  DNGqgsIpvlh  ...             NaN      NaN      NaN
# 1736  2794742161855193595  Video  CbI6zBkL6H7  ...             NaN      NaN      NaN
# 1737  3549223418228998001  Video  DFBX-TwCX9x  ...             NaN      NaN      NaN
# ...

# %%
test_url = df["videoUrl"][3]

# %%
import requests

def download_video(url, filename):
    """
    Downloads a video from a given URL and saves it to a specified filename.

    Args:
        url (str): The URL of the video to download.
        filename (str): The local filename to save the video as.
    """
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Raise an exception for bad status codes (4xx or 5xx)

        with open(filename, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"Video downloaded successfully to {filename}")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading video: {e}")

# %%
output_filename = "cats.mp4"        # Replace with your desired filename
download_video(test_url, output_filename)
# Out:
# Video downloaded successfully to cats.mp4
