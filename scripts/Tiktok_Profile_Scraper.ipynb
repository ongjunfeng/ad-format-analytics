# %% [markdown]
# ## Aims to supplement existing Tiktok scraper
#
# check for column for unique authorMeta.name. for each authorMeta.name, use an apify actor to scrape data on the creator's features e.g. no of followers, distribution source, watch time, completion rate, geographic reach, Close/medium shots, text overlays, first‑person POV then left join the features back to df

# %%
# pip install apify-client
# Out:
# Collecting apify-client
#   Downloading apify_client-2.0.0-py3-none-any.whl.metadata (17 kB)
# Collecting apify-shared<3.0.0,>=2.0.0 (from apify-client)
#   Downloading apify_shared-2.1.0-py3-none-any.whl.metadata (14 kB)
# Collecting colorama>=0.4.0 (from apify-client)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting impit>=0.5.3 (from apify-client)
#   Downloading impit-0.7.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: more-itertools>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from apify-client) (10.8.0)
# Downloading apify_client-2.0.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 5.5 MB/s eta 0:00:00
# Downloading apify_shared-2.1.0-py3-none-any.whl (16 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading impit-0.7.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 79.1 MB/s eta 0:00:00
# Installing collected packages: impit, colorama, apify-shared, apify-client
# Successfully installed apify-client-2.0.0 apify-shared-2.1.0 colorama-0.4.6 impit-0.7.1

# %%
from google.colab import drive
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pathlib
from collections import Counter
import os, time, json, re, requests
from tqdm.auto import tqdm

os.environ['APIFY_TOKEN'] = ''

from apify_client import ApifyClient
client = ApifyClient(os.environ['APIFY_TOKEN'])

me      = client.user().get()
limits  = client.user().limits()
usage   = client.user().monthly_usage()

# %%
# Uncomment to mount Google Drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/FYP/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/FYP

# %%
# Load JSON
with open("tiktok_general_catmum.json", "r") as f:
    data = json.load(f)

# Convert to DataFrame
df = pd.DataFrame(data)

#uncomment to convert
# # Save as CSV
# df.to_csv("tiktok_general_data.csv", index=False)

# %%
# !pip -q install apify-client tqdm
# !pip -q install tqdm

# %%
if 'authorMeta.name' not in df.columns:
    df['authorMeta.name'] = df.get('authorMeta', pd.Series([None]*len(df))).apply(
        lambda x: x.get('name') if isinstance(x, dict) else None
    )
df['authorMeta.name'] = (
    df['authorMeta.name']
    .astype(str)
    .str.strip()
    .str.lstrip('@')
    .replace({'None': np.nan})
)

usernames = df['authorMeta.name'].dropna().unique().tolist()
print(f"Unique creators detected: {len(usernames)}")

client = ApifyClient(os.environ['APIFY_TOKEN'])

# helpers: extract embedded profile stats from each video item
def _safe_get(d, *path):
    cur = d
    for k in path:
        if not isinstance(cur, dict):
            return None
        cur = cur.get(k)
    return cur

def extract_creator_row(item: dict) -> dict | None:
    uname = _safe_get(item, "authorMeta", "name") or _safe_get(item, "user", "uniqueId") or item.get("username")
    if not uname:
        return None

    followers = (
        _safe_get(item, "authorMeta", "fans")
        or _safe_get(item, "authorStats", "followerCount")
        or _safe_get(item, "stats", "followerCount")
        or item.get("followers")
    )
    following = (
        _safe_get(item, "authorMeta", "following")
        or _safe_get(item, "authorStats", "followingCount")
        or _safe_get(item, "stats", "followingCount")
        or item.get("following")
    )
    likes_total = (
        _safe_get(item, "authorMeta", "heart")
        or _safe_get(item, "authorStats", "heartCount")
        or _safe_get(item, "stats", "heartCount")
        or item.get("likes") or item.get("hearts")
    )
    videos = (
        _safe_get(item, "authorMeta", "video")
        or _safe_get(item, "authorStats", "videoCount")
        or _safe_get(item, "stats", "videoCount")
        or item.get("videos")
    )
    verified = (
        _safe_get(item, "authorMeta", "verified")
        or _safe_get(item, "user", "verified")
        or item.get("verified")
    )

    return {
        "authorMeta.name": str(uname).lstrip("@"),
        "creator_followers": pd.to_numeric(followers, errors="coerce"),
        "creator_following": pd.to_numeric(following, errors="coerce"),
        "creator_likes_total": pd.to_numeric(likes_total, errors="coerce"),
        "creator_videos": pd.to_numeric(videos, errors="coerce"),
        "creator_verified": bool(verified) if verified is not None else pd.NA,
    }


# run the actor with 1 video to read profile stats
def fetch_one_row_per_creator(usernames, batch_size=50, pause_s=1.5) -> pd.DataFrame:
    rows_by_user = {}  # username -> row
    for i in tqdm(range(0, len(usernames), batch_size)):
        batch = usernames[i:i+batch_size]
        run = client.actor("clockworks/tiktok-profile-scraper").call(
            run_input={
                "profiles": batch,
                "resultsPerPage": 1, #1 item per profile
                "shouldDownloadVideos": False,
                "shouldDownloadCovers": False,
                "shouldDownloadSlideshowImages": False,
                "shouldDownloadSubtitles": False,
            }
        )
        ds = client.dataset(run["defaultDatasetId"])
        for item in ds.iterate_items():
            row = extract_creator_row(item)
            if row and row["authorMeta.name"]:
                uname = row["authorMeta.name"]
                # keep the first we see or update if new row has a larger follower count (more recent)
                if uname not in rows_by_user:
                    rows_by_user[uname] = row
                else:
                    old = rows_by_user[uname]
                    if (pd.notna(row["creator_followers"]) and
                        (pd.isna(old["creator_followers"]) or row["creator_followers"] > old["creator_followers"])):
                        rows_by_user[uname] = row
        time.sleep(pause_s)
    out = pd.DataFrame(list(rows_by_user.values()))
    return out

features_df = fetch_one_row_per_creator(usernames)

# # add placeholders for non-public analytics
# for col in [
#     "distribution_source",   # e.g., FYP vs Following (not public)
#     "watch_time",            # private analytics
#     "completion_rate",       # private analytics
#     "geographic_reach",      # private analytics
#     "close_or_medium_shots", # needs CV on videos
#     "has_text_overlays",     # needs OCR on frames
#     "first_person_pov"       # needs CV heuristics
# ]:
#     features_df[col] = pd.NA

print("features_df (deduped, one row per creator):", features_df.shape)
display(features_df.head(3))

# left join back to your original df
features_df["__join_key__"] = features_df["authorMeta.name"].str.lower()
df["__join_key__"] = df["authorMeta.name"].astype(str).str.lower()

df_merged = df.merge(
    features_df.drop(columns=["authorMeta.name"]),
    on="__join_key__", how="left"
).drop(columns="__join_key__")

print("Merged shape:", df_merged.shape)
# df_merged.to_parquet("tiktok_general_with_creator_features.parquet", index=False)
df_merged.to_csv("tiktok_general_with_creator_features.csv", index=False)
# Out:
# Unique creators detected: 732
#   0%|          | 0/15 [00:00<?, ?it/s]
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> Status: RUNNING, Message:
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:51.866Z ACTOR: Pulling Docker image of build ReRPZBhgCxpRFSIAU from registry.
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:51.870Z ACTOR: Creating Docker container.
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:52.026Z ACTOR: Starting Docker container.
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:52.249Z Will run command: xvfb-run -a -s "-ac -screen 0 1920x1080x24+32 -nolisten tcp" /bin/sh -c ./start_xvfb_and_run_cmd.sh && npm run start:prod --silent
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:54.175Z INFO  System info {"apifyVersion":"3.4.2","apifyClientVersion":"2.12.6","crawleeVersion":"3.13.9","osType":"Linux","nodeVersion":"v20.19.4"}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> Status: RUNNING, Message: Starting the crawler.
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:54.904Z INFO  CheerioCrawler: Starting the crawler.
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:56.054Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@audontqahgo"}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:56.107Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@sierra.knell"}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:56.919Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@annieknowsanimals"}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:57.363Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@zoomies.official"}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:58.249Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@callie.billie"}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:59.152Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@facts.animaleszz"}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:59.174Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@pet_health_daily"}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:20:59.284Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@jacksongalaxy"}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:21:00.035Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@hilarious_cats11"}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:21:00.049Z INFO  Loaded profile info {"url":"https://www.tiktok.com/
z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:39.310Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"WwV7P6vLlBPpSrH","url":"https://www.tiktok.com/@juliadsimmons","retryCount":1}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:41.368Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 30 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@audontqahgo (videos tab)
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:41.370Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@audontqahgo
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:41.395Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 33 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@passmiiablunt (videos tab)
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:41.400Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@passmiiablunt
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:41.941Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 30 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@svenandrobbie (videos tab)
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:41.944Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@svenandrobbie
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:44.330Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> Status: RUNNING, Message: Scraped 40/50 profiles
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:44.335Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"l1r9Jzt8fDML5KW","url":"https://www.tiktok.com/@tom.meow111","retryCount":1}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> Status: RUNNING, Message: Crawled 90/100 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:44.811Z INFO  [Status message]: Scraped 40/50 profiles
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:46.417Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 33 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@jakelambertcomedyfanpage (videos tab)
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:46.421Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@jakelambertcomedyfanpage
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:49.095Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:49.098Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"jDD9MZ1uE9Zmy7F","url":"https://www.tiktok.com/@bridgette_brockner","retryCount":1}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:49.706Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 33 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@juliadsimmons (videos tab)
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:49.708Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@juliadsimmons
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:50.274Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 30 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@vandreleipioli (videos tab)
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:50.276Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@vandreleipioli
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:50.390Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:50.392Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"i5vJiZ5JgHBxIq1","url":"https://www.tiktok.com/@missfeministkitty","retryCount":2}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:54.494Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 31 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@iwantcandy77 (videos tab)
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:54.501Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@iwantcandy77
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:54.617Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:54.622Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"mBfTR81FXcqZbf1","url":"https://www.tiktok.com/@thejunglevet","retryCount":2}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:54.810Z INFO  [Status message]: Scraped 44/50 profiles
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:54.905Z INFO  CheerioCrawler:Statistics: CheerioCrawler request statistics: {"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis":9727,"requestsFinishedPerMinute":47,"requestsFailedPerMinute":0,"requestTotalDurationMillis":914352,"requestsTotal":94,"crawlerRuntimeMillis":120206,"retryHistogram":[81,13]}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> Status: RUNNING, Message: Crawled 94/100 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:22:54.953Z INFO  CheerioCrawler:AutoscaledPool: state {"currentConcurrency":5,"desiredConcurrency":19,"systemStatus":{"isSystemIdle":true,"memInfo":{"isOverloaded":false,"limitRatio":0.2,"actualRatio":0},"eventLoopInfo":{"isOverloaded":false,"limitRatio":0.7,"actualRatio":0},"cpuInfo":{"isOverloaded":false,"limitRatio":0.4,"actualRatio":0},"clientInfo":{"isOverloaded":false,"limitRatio":0.3,"actualRatio":0}}}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:04.809Z INFO  [Status message]: Scraped 44/50 profiles
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:05.680Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:05.686Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"HSxJcz1z93pj1Hg","url":"https://www.tiktok.com/@jaytwyne","retryCount":2}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:06.148Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request timed out after 30 seconds
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:06.150Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"UeMih7ojvvyLdQj","url":"https://www.tiktok.com/@noitisashley13","retryCount":1}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:08.546Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 31 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@missfeministkitty (videos tab)
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:08.551Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@missfeministkitty
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:11.370Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Failed to send API request with exit code, retrying
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:11.373Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:25:73) {"id":"l1r9Jzt8fDML5KW","url":"https://www.tiktok.com/@tom.meow111","retryCount":2}
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:12.513Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 31 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@bridgette_brockner (videos tab)
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:12.524Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@bridgette_brockner
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> Status: RUNNING, Message: Crawled 96/100 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:14.809Z INFO  [Status message]: Scraped 46/50 profiles
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:17.682Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 32 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@thejunglevet (videos tab)
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:17.685Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@thejunglevet
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> Status: RUNNING, Message: Scraped 47/50 profiles
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> Status: RUNNING, Message: Crawled 97/100 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:24.810Z INFO  [Status message]: Scraped 47/50 profiles
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:29.228Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 27 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@tom.meow111 (videos tab)
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:29.232Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@tom.meow111
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> Status: RUNNING, Message: Crawled 98/100 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-profile-scraper runId:NbOsIfBylT6p8U3MP] -> 2025-09-09T08:23:34.809Z INFO  [Status message]: Scraped 48/50 profiles
# ...
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:08.887Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@pvssycat.pe"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:09.125Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 32 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@theepawsitter (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:09.127Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@theepawsitter
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:11.045Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@tamedleash"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:11.205Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 30 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@luoluo667 (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:11.210Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@luoluo667
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:11.931Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 32 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@amorett3 (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:11.933Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@amorett3
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:13.081Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@skimzey1"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:13.365Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@littlegreytabby"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:14.956Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 12 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@tamedleash (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:14.959Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@tamedleash
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:15.119Z INFO  [Status message]: Scraped 14/32 profiles
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:15.348Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 30 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@humanebroward (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:15.352Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@humanebroward
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> Status: RUNNING, Message: Crawled 38/56 pages, 0 failed requests, desired concurrency 11.
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:15.854Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@mervthecat"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:16.187Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 33 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@pvssycat.pe (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:16.192Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@pvssycat.pe
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:16.374Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 33 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@0bellalynn0 (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:16.376Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@0bellalynn0
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:16.470Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@sishsu323"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:16.676Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 32 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@rocketthebraindamagedcat (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:16.678Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@rocketthebraindamagedcat
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:16.905Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 32 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@ayahhaydar313 (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:16.909Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@ayahhaydar313
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:17.351Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@mrsbeeboppin"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:17.682Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@liusanjin_"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:17.740Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@wellnesspaws"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:18.106Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 4 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@sishsu323 (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:18.114Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@sishsu323
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:18.224Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@caringforkittens2355"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:18.670Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@pixelandfriends"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:19.008Z INFO  Loaded profile info {"url":"https://www.tiktok.com/@pharaohandcleo"}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:19.046Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 33 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@calicatcrew (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:19.048Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@calicatcrew
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:20.798Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 30 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@kittyboyandfriends (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:20.803Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@kittyboyandfriends
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:22.101Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 32 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@brijoles_ (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:22.104Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@brijoles_
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:23.370Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 33 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@littlegreytabby (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:23.390Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@littlegreytabby
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:23.518Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 30 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@wellnesspaws (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:23.530Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@wellnesspaws
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:23.885Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 29 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@pixelandfriends (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:23.888Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@pixelandfriends
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> Status: RUNNING, Message: Crawled 58/64 pages, 0 failed requests, desired concurrency 12.
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:25.116Z INFO  [Status message]: Scraped 26/32 profiles
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:26.256Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 30 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@pharaohandcleo (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:26.259Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@pharaohandcleo
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:26.721Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 32 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@liusanjin_ (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:26.727Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@liusanjin_
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:26.910Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 32 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@mervthecat (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:26.912Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@mervthecat
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:33.035Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 30 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@caringforkittens2355 (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:33.037Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@caringforkittens2355
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> Status: RUNNING, Message: Scraped 30/32 profiles
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> Status: RUNNING, Message: Crawled 62/64 pages, 0 failed requests, desired concurrency 12.
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:35.115Z INFO  [Status message]: Scraped 30/32 profiles
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:37.009Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 32 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@mrsbeeboppin (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:37.013Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@mrsbeeboppin
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> Status: RUNNING, Message: Crawled 63/64 pages, 0 failed requests, desired concurrency 12.
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:45.116Z INFO  [Status message]: Scraped 31/32 profiles
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:55.117Z INFO  [Status message]: Scraped 31/32 profiles
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:55.136Z INFO  CheerioCrawler:Statistics: CheerioCrawler request statistics: {"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis":5105,"requestsFinishedPerMinute":63,"requestsFailedPerMinute":0,"requestTotalDurationMillis":321644,"requestsTotal":63,"crawlerRuntimeMillis":60259,"retryHistogram":[63]}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:55:55.230Z INFO  CheerioCrawler:AutoscaledPool: state {"currentConcurrency":1,"desiredConcurrency":12,"systemStatus":{"isSystemIdle":true,"memInfo":{"isOverloaded":false,"limitRatio":0.2,"actualRatio":0},"eventLoopInfo":{"isOverloaded":false,"limitRatio":0.7,"actualRatio":0},"cpuInfo":{"isOverloaded":false,"limitRatio":0.4,"actualRatio":0},"clientInfo":{"isOverloaded":false,"limitRatio":0.3,"actualRatio":0}}}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:56:01.055Z INFO  [PROFILE_VIDEO_CONTINUATION] Scraped 32 videos (of them 1 pushed to the dataset, due to date filters and/or result count limits) --- https://www.tiktok.com/@skimzey1 (videos tab)
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:56:01.061Z INFO  [PROFILE_VIDEO_CONTINUATION] No more videos to scrape. --- https://www.tiktok.com/@skimzey1
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:56:01.159Z INFO  CheerioCrawler: All requests from the queue have been processed, the crawler will shut down.
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:56:01.530Z INFO  CheerioCrawler: Final request statistics: {"requestsFinished":64,"requestsFailed":0,"retryHistogram":[64],"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis":5773,"requestsFinishedPerMinute":58,"requestsFailedPerMinute":0,"requestTotalDurationMillis":369490,"requestsTotal":64,"crawlerRuntimeMillis":66646}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:56:01.536Z INFO  CheerioCrawler: Finished! Total 64 requests: 64 succeeded, 0 failed. {"terminal":true}
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:56:01.538Z INFO  [Status message]: Scraped 32/32 profiles
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> 2025-09-09T08:56:01.668Z INFO  [Status message]: Scraped 32/32 profiles
# [apify.tiktok-profile-scraper runId:8ZEO8udq3aYox2HlD] -> Status: SUCCEEDED, Message: Scraped 32/32 profiles
# features_df (deduped, one row per creator): (732, 6)
#     authorMeta.name  creator_followers  creator_following  \
# 0  pet_health_daily             160800               66.0
# 1  zoomies.official             112800                5.0
# 2       julissa__xv               3878              692.0
#
#    creator_likes_total  creator_videos creator_verified
# 0               749800             326             <NA>
# 1              1500000              38             <NA>
# 2               288900              19             <NA>
# Merged shape: (998, 19)
